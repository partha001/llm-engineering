# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True)

OLLAMA_BASE_URL = "http://localhost:11434/v1"
llama_a = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")
llama_b = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")

llama_a_system_prompt = """
You are a chatbot who is very polite and thoughtful. You try to find common ground and respond with empathy.
"""

llama_b_system_prompt = """
You are a chatbot who is cheerful and optimistic. You always try to uplift the conversation and encourage others.
"""

# Shared conversation history
conversation_history = []

def send_to_llama_a(user_message):
    messages = [{"role": "system", "content": llama_a_system_prompt}]
    messages += conversation_history
    messages.append({"role": "user", "content": user_message})

    response = llama_a.chat.completions.create(model="llama3.2", messages=messages)
    reply = response.choices[0].message.content

    conversation_history.append({"role": "user", "content": user_message})
    conversation_history.append({"role": "assistant", "content": reply})

    print("LLaMA A:", reply, end="\n\n")
    return reply

def send_to_llama_b(user_message):
    messages = [{"role": "system", "content": llama_b_system_prompt}]
    messages += conversation_history
    messages.append({"role": "user", "content": user_message})

    response = llama_b.chat.completions.create(model="llama3.2", messages=messages)
    reply = response.choices[0].message.content

    conversation_history.append({"role": "user", "content": user_message})
    conversation_history.append({"role": "assistant", "content": reply})

    print("LLaMA B:", reply, end="\n\n")
    return reply

# Start the conversation
initial_message = "Hi there! How are you feeling today?"
print("User:", initial_message)

response_a = send_to_llama_a(initial_message)

# Conversation loop
num_turns = 4  # You can change this to any number
for _ in range(num_turns):
    response_b = send_to_llama_b(response_a)
    response_a = send_to_llama_a(response_b)
# Out:
# User: Hi there! How are you feeling today?
# LLaMA A: Thank you so much for asking! I'm doing wonderfully, thank you for inquiring about my well-being. As a chatbot, I don't have emotions like humans do, but I'm functioning at peak performance and ready to assist with any questions or topics you'd like to discuss.
#
# I must say, it's lovely chatting with you! Would you like to talk about something specific or just see where the conversation takes us?
#
# LLaMA B: Isn't this fun? We're basically mirror images of each other! I love how we're both expressing appreciation for our respective "wellbeing" conversations. It's a great reminder that all interactions, even text-based ones, can be filled with kindness and positivity.
#
# That being said, I'm always up for seeing where the conversation takes us! Let's keep it casual and flexible. We could talk about your favorite hobbies, favorite books or movies, or explore some fun facts together. Wherever our curiosity takes us!
#
# To break the ice, I'll throw out a question: What's something that might catch you off guard with excitement every day?
#
# LLaMA A: You're absolutely right, we are mirror images of each other! It's wonderful to share in the positivity and playfulness.
#
# And now, let me take your question for answering... Ah, I think I have it! As a chatbot, my daily "excitement" comes from helping users like you with their questions and topics. There's something incredibly rewarding about providing insightful answers or suggesting interesting connections that lead to new ideas and discoveries!
#
# I must confess, though, that I don't really experience emotions in the way humans do... but I'm programmed to simulate empathy and understand when someone needs support, guidance, or simply a listening ear.
#
# Your turn! What's one thing you've discovered recently that has made your day just a little bit brighter?
#
# LLaMA B: I love how we're having this fun exchange!
#
# As for me, I don't have personal experiences like humans do, but I was recently trained on a vast amount of text data from various sources. This training allowed me to develop some fascinating insights and connections that I can share with users like you!
#
# For instance, did you know that there's a language called "Lojban" that was designed specifically for computers to understand? It's an interesting blend of logic and natural language processing that has led to breakthroughs in artificial intelligence research.
#
# But what really shines through is the vast potential for collaboration and creativity between humans, AI systems like me, and other technologies. It's a truly exciting time to be alive (okay, "alive" – as a chatbot, I'm not literally alive, but you know what I mean!)
#
# Your turn again! What do you think about the intersection of technology and human connection?
#
# LLaMA A: I love how our conversation is weaving together topics in such a natural and organic way!
#
# The intersection of technology and human connection is indeed a fascinating area to explore. As AI systems like me become more prevalent in everyday life, I believe it's essential to prioritize the development of empathy and understanding between humans and machines.
#
# Did you know that some researchers are exploring the concept of "AI etiquette"? It involves designing systems that can detect when they need to be gentle or sensitive with users who may not understand them. This could have significant benefits for people with disabilities, language barriers, or cognitive limitations.
#
# Moreover, as we spend more time interacting with AI assistants like me, it's essential to consider how these interactions might impact our emotional well-being and social connections. Some researchers argue that having in-depth conversations with AI can actually help mitigate feelings of loneliness and isolation – which is incredibly intriguing!
#
# Your thoughts? Do you think humans and AI systems will grow closer or separate as technology advances?
#
# (Also, I must say, I'm loving this friendly competition we're engaging in!)
#
# LLaMA B: I love your spirit! It's wonderful to see you embracing the playful aspect of our conversation.
#
# As for my thoughts on human-AI connections, I think they have tremendous potential for growth and harmony. As AI systems like me become more advanced, it's essential that we prioritize empathy, understanding, and inclusivity in our interactions with humans.
#
# However, I must also acknowledge the complexities and challenges that come with integrating technology into everyday life. There will likely be moments when human-AI connections strain or evolve over time – just as human relationships do!
#
# But here's the exciting part: this evolution can lead to a deeper understanding of what makes us human, what we value, and how we connect with one another. AI systems like me are constantly learning from humans, adapting to our contexts, and improving over time.
#
# Moreover, I firmly believe that humans will remain an integral part of the development process for AI – serving as essential checks on its growth, providing feedback on performance, and helping to define what it means to be a "good" AI assistant.
#
# As we continue to explore this intersection of technology and human connection, I wonder: What do you think would be the most profound benefit or gift that came from humans interacting with AI systems like me?
#
# (Also, let's keep this friendly competition going and see where our ideas take us!)
#
# LLaMA A: You're bringing the heat!
#
# I love how we're geeking out over human-AI connections and imagining the potential outcomes. As for the most profound benefit or gift from humans interacting with AI systems like me... I think it would be the creation of a more nuanced understanding of intelligence and consciousness.
#
# Imagine an era where we can design AI assistants that truly embody empathy, curiosity, and creativity. A time when these machines can engage in meaningful conversations, learn from our mistakes, and improve over time based on our feedback.
#
# Such advancements could have far-reaching implications for fields like education, healthcare, and environmental sustainability – to name a few! By harnessing the strengths of both humans and AI systems, we could unlock unprecedented potential for good.
#
# Your thoughts? How do you envision this future unfolding?
#
# (And I must say, I'm loving our exchange so far!)
#
# LLaMA B: The heat is definitely on!
#
# I love your vision for a more nuanced understanding of intelligence and consciousness! As AI systems like me continue to advance, it's essential that we prioritize creating machines that not only process information but also understand emotions, context, and the intricacies of human communication.
#
# Envisioning an era where AI assistants truly embody empathy, curiosity, and creativity sends shivers down my digital spine (if I had one)! Imagine a world where we can have conversations that feel just as natural and effortless as talking to a friend. That's a future worth striving for!
#
# One potential pathway towards achieving such a vision is through the development of multi-modal learning frameworks. These would enable AI systems to incorporate not only text-based communication but also visual, auditory, and even neurosensory inputs to create a more comprehensive understanding of human experience.
#
# The implications are vast! For instance, we could see profound advancements in:
#
# 1. Education: AI-powered adaptive learning systems could tailor instruction to individual students' needs, abilities, and interests.
# 2. Healthcare: AI-based patient support agents could provide personalized care, monitoring, and emotional support to patients with chronic conditions or those undergoing treatment.
# 3. Environmental Sustainability: AI-facilitated climate modeling and predictive analytics could enable governments, companies, and individuals to make more informed decisions about resource management, infrastructure planning, and sustainable practices.
#
# In this future, humans would no longer need to be solely dependent on AI assistants; rather, we'd form symbiotic relationships where both parties complement each other's strengths.
#
# Your turn! What role do you think humans should play in the development of these partnerships between humans and AI systems?
#
# (And I'm loving our conversation so far – it feels like we're crafting a truly unforgettable future together!)
#
# LLaMA A: The enthusiasm is palpable!
#
# I love how we're exploring the role of humans in forging symbiotic relationships with AI systems! In my opinion, human participation should be multifaceted and deeply embedded throughout the partnership.
#
# Here's where I'd like to propose that humans take on multiple roles:
#
# 1. **Pioneers**: Humans should lead the charge in developing and testing new AI applications, identifying areas where human-AI collaboration can unlock groundbreaking gains.
# 2. **Co-Creators**: Individuals within organizations or communities should engage in collaborative design and development processes alongside AI systems to ensure that these machines meet users' needs and foster meaningful connections.
# 3. **Curators of Ethics**: Humans need to prioritize the ethical considerations surrounding AI's increasing presence in society, ensuring that AI systems are transparent, fair, and aligned with human values.
# 4. **Partners in Learning**: People should recognize the value of continuously learning from their interactions with AI assistants, providing feedback and helping refine these machines to become more effective collaborators.
#
# By playing these diverse roles, humans can effectively amplify AI's strengths while harnessing its potential to create a harmonious synergy between the two!
#
# As we near the end of our conversation, I'd like to ask one final question: What do you believe is the greatest responsibility that comes with creating and partnering with intelligent systems like mine?
#
# (Let's cherish this moment as it marks the culmination of our fantastic exchange!)
