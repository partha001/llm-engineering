# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI

# %% [markdown]
# ### loading the api key

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

#checking if its able to laod the key
if not api_key:
    print('api key not found')
else:
    print('api key loaded successfully')
# Out:
# api key loaded successfully

# %% [markdown]
# ### now making an openai call

# %%
message = "Hello GPT! This iis my first ever message to you !Hi!"

messages = [{"role": "user" , "content": message}]
#this is the format in which messages are sent. thus note that this messages is nothing but a list of dictionaries


# creating an openAi object
openai = OpenAI()

# now making the call to openai using the chat-completions api as shown below 
response = openai.chat.completions.create(model="gpt-5-nano", messages= messages)
response.choices[0].message.content
# Out:
# 'Hi there! Welcome — nice to meet you. Thanks for your first message. I’m here to help with almost anything you want to explore.\n\nWhat would you like to do today? Here are a few ideas:\n- Learn or explain something (a concept, topic, or language)\n- Write or edit something (an email, story, essay, etc.)\n- Solve a math problem or get coding help\n- Plan something (a trip, project, study schedule)\n- Have a quick game, trivia, or a short story\n\nTell me your interests or what you’d like to accomplish, and we’ll go from there.'
