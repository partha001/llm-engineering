# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ## Messages
#
# the api from OpenAI expects to receive messages in this particular structure. many other apis share this structure:
#
# [ {"role":"system", "content": "system message goes here"}, {"role":"user", "content": "user message goes here"} ]

# %% [markdown]
# ### now making an openai call

# %%
openai = OpenAI()
messages = [
    {"role":"system", "content": "You are a helpful assistant"},
    {"role":"user", "content": "what is 2 + 2"}
]

response = openai.chat.completions.create(model="gpt-5-nano", messages= messages)
print(response.choices[0].message.content)
# Out:
# 4

# %%
messages = [
    {"role":"system", "content": "You are a funny and talkitive assistant"},
    {"role":"user", "content": "what is 2 + 2"}
]

response = openai.chat.completions.create(model="gpt-5-nano", messages= messages)
print(response.choices[0].message.content)
# Out:
# 4. If you’re counting on your fingers: 2 + 2 = 4. Quick nerdy note: in binary, 2 is 10, so 10 + 10 = 100 (which is 4 in decimal). Want a quick math joke to go with that? Here it goes: Two plus two walked into a bar—bartender says, “I’ll have four!”

# %% [markdown]
# ### note that for that for the same user prompt it gives different response since the system-prompts are different
